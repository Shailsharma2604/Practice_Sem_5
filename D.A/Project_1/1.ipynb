# %% [markdown]
# # Project_1 fro Data Analytics (D.A.)

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Reading csv

# %%
data=pd.read_csv("51 - car-sales.csv")

# %% [markdown]
# ## Viewing data

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Datatypes of data

# %%
data.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %% [markdown]
# ## Head of the data

# %%
data.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %% [markdown]
# ## Tail of the data

# %%
data.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %% [markdown]
# ## Checking the infomation of the data

# %%
data.info
# Out:
# <bound method DataFrame.info of      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00>

# %% [markdown]
# ## Droping NULL values

# %%
data.dropna()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## shape of the data

# %%
data.shape
# Out:
# (10, 5)

# %% [markdown]
# ## Changing the data shape using tarnspose

# %%
data.T
# Out:
#                        0          1          2           3          4  \
# Make              Toyota      Honda     Toyota         BMW     Nissan
# Colour             White        Red       Blue       Black      White
# Odometer (KM)     150043      87899      32549       11179     213095
# Doors                  4          4          3           5          4
# Price          $4,000.00  $5,000.00  $7,000.00  $22,000.00  $3,500.00
#
#                        5          6          7          8          9
# Make              Toyota      Honda      Honda     Toyota     Nissan
# Colour             Green       Blue       Blue      White      White
# Odometer (KM)      99213      45698      54738      60000      31600
# Doors                  4          4          4          4          4
# Price          $4,500.00  $7,500.00  $7,000.00  $6,250.00  $9,700.00

# %% [markdown]
# ## Removing extra symbol '$ , .00'

# %%
data['Price'] = data['Price'].str.replace('$', '')
data['Price'] = data['Price'].str.replace(',', '')
data['Price'] = data['Price'].str.replace('.00', '')

# %% [markdown]
# ## Check the data type again

# %%
data.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %% [markdown]
# ## Veiwing data again

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %% [markdown]
# ## Converting the 'Price' column to int 64

# %%
data['Price'] = data['Price'].astype('Int64')

# %% [markdown]
# ## Final view of the data

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %% [markdown]
# ## Final datatypes

# %%
data.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price             Int64
# dtype: object

# %% [markdown]
# ## Final information of the data

# %%
data.info
# Out:
# <bound method DataFrame.info of      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700>

# %% [markdown]
# ## Ploting

# %%
data.plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Histogram

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'Odometer (KM)'}>,
#         <Axes: title={'center': 'Doors'}>],
#        [<Axes: title={'center': 'Price'}>, <Axes: >]], dtype=object)

# %% [markdown]
# ## Bargraph

# %%
data.plot(kind='bar',x='Odometer (KM)',y='Price')
# Out:
# <Axes: xlabel='Odometer (KM)'>

# %%
data.plot(kind='bar',x='Odometer (KM)',y='Doors')
# Out:
# <Axes: xlabel='Odometer (KM)'>

# %% [markdown]
# ## Poting pie chart

# %%
data.plot(kind='pie',x='Odometer (KM)',y='Price')
# Out:
# <Axes: ylabel='Price'>

# %%
data.plot(kind='pie',x='Odometer (KM)',y='Doors')
# Out:
# <Axes: ylabel='Doors'>

# %% [markdown]
# ## Ploting hexbin chart

# %%
data.plot(kind='hexbin',x='Odometer (KM)',y='Doors')
# Out:
# <Axes: xlabel='Odometer (KM)', ylabel='Doors'>

# %%
data.plot(kind='hexbin',x='Odometer (KM)',y='Price')
# Out:
# <Axes: xlabel='Odometer (KM)', ylabel='Price'>

# %% [markdown]
# ## Ploting scatter graph

# %%
data.plot(kind='scatter',x='Odometer (KM)',y='Doors')
# Out:
# <Axes: xlabel='Odometer (KM)', ylabel='Doors'>

# %%
data.plot(kind='scatter',x='Odometer (KM)',y='Price')
# Out:
# <Axes: xlabel='Odometer (KM)', ylabel='Price'>

# %% [markdown]
# ## Ploting area graph

# %%
data.plot(kind='area',x='Odometer (KM)',y='Price')
# Out:
# <Axes: xlabel='Odometer (KM)'>

# %%
data.plot(kind='area',x='Odometer (KM)',y='Doors')
# Out:
# <Axes: xlabel='Odometer (KM)'>

# %% [markdown]
# ## Saving the data into excel

# %%
data.to_excel('1.xlsx', index=False)

# %% [markdown]
# # END
